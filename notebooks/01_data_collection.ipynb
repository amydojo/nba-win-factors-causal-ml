# %% [markdown]
# # NBA Data Collection (2015-2024)
#
# This notebook collects NBA team statistics using the nba_api package.

# %%
import pandas as pd
import numpy as np
from nba_api.stats.endpoints import leaguegamefinder, teamgamelog
from nba_api.stats.static import teams
import os

# %% [markdown]
# ## Fetch Team Statistics
#
# Collect game-level statistics for all NBA teams from 2015-2024 seasons.

# %%
# Example: Load team data
nba_teams = teams.get_teams()
print(f"Total NBA teams: {len(nba_teams)}")

# Seasons to analyze
seasons = ['2015-16', '2016-17', '2017-18', '2018-19', '2019-20', 
           '2020-21', '2021-22', '2022-23', '2023-24']

# %% [markdown]
# ## Save Processed Data
#
# Save cleaned team statistics to data/processed/ directory.

# %%
# Placeholder for saving data
# df.to_csv('../data/processed/nba_team_stats.csv', index=False)
print("Data collection complete. Results saved to data/processed/")
