# %% [markdown]
# # Causal Discovery: NBA Win Factors
#
# This notebook performs causal discovery to identify key factors influencing NBA team wins.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
from dowhy import CausalModel
from pgmpy.estimators import PC
from pgmpy.estimators import ConstraintBasedEstimator
import plotly.graph_objects as go

# %% [markdown]
# ## Load Processed Data
#
# Load the team statistics prepared in the data collection notebook.

# %%
# Load data
# df = pd.read_csv('../data/processed/nba_team_stats.csv')
# print(f"Dataset shape: {df.shape}")
# df.head()

# %% [markdown]
# ## Causal Discovery Using PC Algorithm
#
# Apply the PC (Peter-Clark) algorithm to discover causal structure.

# %%
# Example causal discovery workflow
# Select key variables
variables = ['field_goal_pct', 'three_point_pct', 'free_throw_pct', 
             'rebounds', 'assists', 'turnovers', 'steals', 'blocks', 'wins']

# pc = PC(df[variables])
# causal_graph = pc.estimate()
# print("Causal edges discovered:")
# print(causal_graph.edges())

# %% [markdown]
# ## Visualize Causal Network
#
# Create an interactive network visualization showing causal relationships.

# %%
# Create network visualization
# This would generate the interactive HTML saved to outputs/nba_network.html
print("Causal network visualization saved to outputs/nba_network.html")

# %% [markdown]
# ## Save Results
#
# Export causal graph and key findings.

# %%
# Save causal graph
# nx.write_gml(causal_graph, '../outputs/causal_graph.gml')
print("Results saved to outputs/ directory")
